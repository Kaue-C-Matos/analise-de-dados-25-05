# %%
import pandas as pd
df = pd.read_csv('natacao.csv')

# %%
df
# Out:
#            Sede   Ano Distancia  Estilo  Revesamento?     Genero Equipe  \
# 0         Tokyo  2020      100m  Costas             0  Masculino    ROC
# 1         Tokyo  2020      100m  Costas             0  Masculino    ROC
# 2         Tokyo  2020      100m  Costas             0  Masculino    USA
# 3         Tokyo  2020      100m  Costas             0  Masculino    ITA
# 4         Tokyo  2020      100m  Costas             0  Masculino    CHN
# ...         ...   ...       ...     ...           ...        ...    ...
# 4354  Stockholm  1912     4x100   Livre             1   Feminino    SWE
# 4355  Stockholm  1912     4x200   Livre             1  Masculino    AUS
# 4356  Stockholm  1912     4x200   Livre             1  Masculino    USA
# 4357  Stockholm  1912     4x200   Livre             1  Masculino    GBR
# 4358  Stockholm  1912     4x200   Livre             1  Masculino    GER
#
#                                                  Atleta            Tempo  \
# ...

# %% [markdown]
# ## **1-Identifique e responda, qual a variável estatística representada em cada coluna do dataframe?**
# ## R: Qualitativas nominais: sede, estilo, genero, equipe, atleta, revesamento;
# ##    Qualitativas ordinais: posicao
# ##    Quantitativas discretas: ano
# ##    Quantitativas contínuas: distancia, tempo

# %% [markdown]
# ## **2-Identifique e responda, qual a medida de resumo mais adequada para cada variável numérica? justifique cada uma delas.**
# ## R: ano: moda, para ver qual ano teve mais jogos
# ##    distância: mediana, pois é o que melhor se encaixa
# ##    tempo: média, para ver a média do tempo dos corredores
# ##    posicao: moda, para ver em qual posição mais pessoas ficaram

# %% [markdown]
# ## **3-Qual atleta teve o maior número de participações em provas masculinas?**

# %%
atletasMasculino = df.loc[df['Genero'] == "Masculino"]
atletasMasculino
# Out:
#            Sede   Ano Distancia  Estilo  Revesamento?     Genero Equipe  \
# 0         Tokyo  2020      100m  Costas             0  Masculino    ROC
# 1         Tokyo  2020      100m  Costas             0  Masculino    ROC
# 2         Tokyo  2020      100m  Costas             0  Masculino    USA
# 3         Tokyo  2020      100m  Costas             0  Masculino    ITA
# 4         Tokyo  2020      100m  Costas             0  Masculino    CHN
# ...         ...   ...       ...     ...           ...        ...    ...
# 4350  Stockholm  1912      400m   Livre             0  Masculino    ANZ
# 4355  Stockholm  1912     4x200   Livre             1  Masculino    AUS
# 4356  Stockholm  1912     4x200   Livre             1  Masculino    USA
# 4357  Stockholm  1912     4x200   Livre             1  Masculino    GBR
# 4358  Stockholm  1912     4x200   Livre             1  Masculino    GER
#
#                                                  Atleta            Tempo  \
# ...

# %%
atletasMasculino['Atleta'].describe()
# Out:
# count               2281
# unique              1504
# top       Michael Phelps
# freq                  18
# Name: Atleta, dtype: object

# %% [markdown]
# ## R: Michael Phelps

# %% [markdown]
# ## **Qual atleta teve o maior número de participações em provas femininas?**

# %%
atletasFemininas = df.loc[df['Genero'] == "Feminino"]
atletasFemininas
# Out:
#            Sede   Ano Distancia  Estilo  Revesamento?    Genero Equipe  \
# 112       Tokyo  2020      100m  Costas             0  Feminino    AUS
# 113       Tokyo  2020      100m  Costas             0  Feminino    CAN
# 114       Tokyo  2020      100m  Costas             0  Feminino    USA
# 115       Tokyo  2020      100m  Costas             0  Feminino    USA
# 116       Tokyo  2020      100m  Costas             0  Feminino    AUS
# ...         ...   ...       ...     ...           ...       ...    ...
# 4318  Stockholm  1912      100m   Livre             0  Feminino    NOR
# 4351  Stockholm  1912     4x100   Livre             1  Feminino    GBR
# 4352  Stockholm  1912     4x100   Livre             1  Feminino    GER
# 4353  Stockholm  1912     4x100   Livre             1  Feminino    AUT
# 4354  Stockholm  1912     4x100   Livre             1  Feminino    SWE
#
#                                                  Atleta            Tempo  \
# ...

# %%
atletasFemininas['Atleta'].describe()
# Out:
# count                      2064
# unique                     1317
# top       Kirsty Leigh Coventry
# freq                         10
# Name: Atleta, dtype: object

# %% [markdown]
# ## R: Kirsty Leigh Coventry

# %%
medalhasBronze = df.loc[df['Posicao'] == 3]
medalhasBronze
# Out:
#            Sede   Ano Distancia     Estilo  Revesamento?     Genero Equipe  \
# 2         Tokyo  2020      100m     Costas             0  Masculino    USA
# 10        Tokyo  2020      100m      Peito             0  Masculino    ITA
# 18        Tokyo  2020      100m  Borboleta             0  Masculino    SUI
# 26        Tokyo  2020      100m      Livre             0  Masculino    ROC
# 34        Tokyo  2020     1500m      Livre             0  Masculino    GER
# ...         ...   ...       ...        ...           ...        ...    ...
# 4329  Stockholm  1912      200m      Peito             0  Masculino    GER
# 4337  Stockholm  1912      400m      Peito             0  Masculino    GBR
# 4345  Stockholm  1912      400m      Livre             0  Masculino    ANZ
# 4352  Stockholm  1912     4x100      Livre             1   Feminino    GER
# 4357  Stockholm  1912     4x200      Livre             1  Masculino    GBR
#
# ...

# %%
medalhasBronze['Equipe'].describe()
# Out:
# count     566
# unique     48
# top       USA
# freq      138
# Name: Equipe, dtype: object

# %% [markdown]
# ## R: USA (Estados Unidos)
